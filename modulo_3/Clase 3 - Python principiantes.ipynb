# %% [markdown]
# # Clase 3: Decisiones y Condicionales en Python
# En esta clase aprenderemos a tomar decisiones dentro de un programa utilizando estructuras condicionales como `if`, `else` y `elif`.
# Esto nos permitirá crear programas que reaccionan de forma distinta según los datos.

# %% [markdown]
# ## ¿Qué es una estructura condicional?
# Una estructura condicional permite ejecutar instrucciones **solo si se cumple una condición**.
# ```python
# if condicion:
#     # código si la condición es verdadera ok
# else:
#     # código si la condición es falsa
# ```

# %%
# Ejemplo simple
edad = 18
if edad >= 18:
    print("Eres mayor de edad")
else:
    print("Eres menor de edad")

# %% [markdown]
# ## Operadores de comparación
# - `==` igual a
# - `!=` distinto de
# - `>` mayor que
# - `<` menor que
# - `>=` mayor o igual
# - `<=` menor o igual
# Vamos a probar algunos:

# %%
# Prueba de operadores
a = 5
b = 8
print(a == b)  # False
print(a != b)  # True
print(a < b)   # True

# %% [markdown]
# ## Estructura `elif`: múltiples condiciones
# Permite verificar varias opciones sin usar muchos `if` anidados:

# %%
nota = 7
if nota >= 9:
    print("Excelente")
elif nota >= 7:
    print("Aprobado")
else:
    print("Desaprobado")

# %% [markdown]
# ## Operadores lógicos: `and`, `or`, `not`
# - `and`: ambas condiciones deben ser verdaderas
# - `or`: al menos una debe ser verdadera
# - `not`: invierte el valor (True ↔ False)

# %%
usuario = "admin"
clave = "1234"
if usuario == "admin" and clave == "1234":
    print("Acceso concedido")
else:
    print("Acceso denegado")

# %% [markdown]
# ## Actividad 1: Clasificador de edades
# Modifica el código para que imprima:
# - "Eres un niño" si la edad es menor de 13
# - "Eres adolescente" si está entre 13 y 17
# - "Eres adulto" si es 18 o más

# %%
# Escribe tu código aquí:
edad = 16
# Tu solución aquí

# %% [markdown]
# ## Actividad 2: Simulador de inicio de sesión
# Usa condicionales para verificar si el usuario y la contraseña coinciden con los valores definidos.

# %%
# Define usuario y clave correcta
usuario_correcto = "usuario1"
clave_correcta = "abcd1234"
# Solicita datos
usuario_ingresado = "usuario1"  # Puedes cambiarlo
clave_ingresada = "abcd1234"     # Puedes cambiarlo
# Validación
# Tu código aquí

# %% [markdown]
# ## Mini Proyecto: Evaluador de notas
# Pide al usuario su nota y evalúa su desempeño usando condicionales. Muestra un mensaje motivador según el resultado.
# **Ejemplo de mensajes:**
# - "¡Excelente trabajo!" (nota >= 9)
# - "Vas bien, sigue así." (nota >= 7 y < 9)
# - "Necesitas mejorar." (nota < 7)

# %%
# Completa el código
nota = 8.5  # Puedes cambiar el valor para probar
# Evaluación con condicionales aquí
